# %% [markdown]
# # Document Clustering
#
# One application of clustering is to finding groups of similar documents.
#
# Let's read in a corpus of BBC articles from 2004-2005. Notice that they are already assigned to 5 general topics: sport, politics, tech, business, and entertainment.

# %%
import pandas as pd
df_bbc = pd.read_csv("https://datasci112.stanford.edu/data/bbc.csv")
df_bbc

# %% [markdown]
# Let's focus on the entertainment topic. Can we further break down these articles into subcategories?

# %%
df_entertainment = df_bbc[df_bbc["topic"] == "entertainment"]
df_entertainment

# %% [markdown]
# This is a job for clustering!
#
# Turn these entertainment articles into a vector representation, and cluster them using $k$-means. (You may have to play around with the number of clusters.)
#
# Manually review a few articles in each cluster. Can you interpret the clusters you found, perhaps assigning a "name" to each one?

# %%
# YOUR CODE HERE
