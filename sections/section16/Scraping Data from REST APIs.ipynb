# %% [markdown]
# # Scraping Data from REST APIs
#
# Many websites make their data readily available using a REST API. Instead of scraping the HTML from a webpage,
#
# - you specify the data that you want by issuing an HTTP request to a URL (called an **endpoint**)
# - the server responds with the data in a convenient format (called a **representation**), such as JSON or XML
#
# To see how this works, we are going to practice with the [REST API](https://rapidapi.com/apidojo/api/tasty) for Tasty, a recipes website.

# %% [markdown]
# ## Preparation (before section)
#
# You will have time to work on these exercises in section. All you need to do before section is:
#
# 1. [create an account](https://rapidapi.com/apidojo/api/tasty) and subscribe to the "Basic" (free) plan
# 2. log in and copy the X-RapidAPI-Key, which is a long string of letters and digits
# 3. paste this key in the `headers` below
#
# If you did everything correctly, then running the cell below should return a JSON object containing all the tags recognized by the Tasty API.

# %%
import requests

domain = "https://tasty.p.rapidapi.com"
endpoint = "tags/list"
url = f"{domain}/{endpoint}"

# TODO: Update the `headers` with your X-RapidAPI-Key.
headers = {
	"X-RapidAPI-Key": "PUT-YOUR-KEY-HERE",
	"X-RapidAPI-Host": "tasty.p.rapidapi.com"
}

# Make an HTTP request to the REST API, get the JSON response.
response = requests.get(url, headers=headers)
response.json()
# Out:
# {'count': 555,
#  'results': [{'display_name': 'Italian',
#    'id': 64453,
#    'name': 'italian',
#    'parent_tag_name': 'european',
#    'root_tag_type': 'cuisine',
#    'type': 'european'},
#   {'display_name': 'Thai',
#    'id': 64460,
#    'name': 'thai',
#    'parent_tag_name': 'asian',
#    'root_tag_type': 'cuisine',
#    'type': 'asian'},
#   {'display_name': 'Vegetarian',
#    'id': 64469,
#    'name': 'vegetarian',
#    'parent_tag_name': 'dietary',
#    'root_tag_type': 'dietary',
#    'type': 'dietary'},
#   {'display_name': 'Under 30 Minutes',
#    'id': 64472,
#    'name': 'under_30_minutes',
#    'parent_tag_name': 'difficulty',
#    'root_tag_type': 'difficulty',
#    'type': 'difficulty'},
#   {'display_name': "Valentine's Day",
#    'id': 64480,
#    'name': 'valentines_day',
#    'parent_tag_name': 'holidays',
#    'root_tag_type': 'seasonal',
#    'type': 'holidays'},
#   {'display_name': 'Breakfast',
#    'id': 64483,
#    'name': 'breakfast',
#    'parent_tag_name': 'meal',
#    'root_tag_type': 'meal',
#    'type': 'meal'},
#   {'display_name': 'Dinner',
#    'id': 64486,
#    'name': 'dinner',
#    'parent_tag_name': 'meal',
#    'root_tag_type': 'meal',
#    'type': 'meal'},
#   {'display_name': 'Kid-Friendly',
#    'id': 64488,
#    'name': 'kid_friendly',
#    'parent_tag_name': 'cooking_style',
#    'root_tag_type': 'cooking_style',
#    'type': 'cooking_style'},
#   {'display_name': 'Happy Hour',
#    'id': 64502,
#    'name': 'happy_hour',
#    'parent_tag_name': None,
#    'root_tag_type': 'occasion',
#    'type': 'occasion'},
#   {'display_name': 'Party',
#    'id': 64503,
#    'name': 'party',
#    'parent_tag_name': 'occasion',
#    'root_tag_type': 'seasonal',
#    'type': 'occasion'},
#   {'display_name': 'Tasty Cookbook',
#    'id': 64506,
#    'name': 'tasty_cookbook',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Blender',
#    'id': 65838,
#    'name': 'blender',
#    'parent_tag_name': 'appliance',
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'Hand Mixer',
#    'id': 65844,
#    'name': 'hand_mixer',
#    'parent_tag_name': None,
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'Microwave',
#    'id': 65845,
#    'name': 'microwave',
#    'parent_tag_name': 'appliance',
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'Stove Top',
#    'id': 65848,
#    'name': 'stove_top',
#    'parent_tag_name': None,
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'Indulgent Sweets',
#    'id': 65850,
#    'name': 'indulgent_sweets',
#    'parent_tag_name': None,
#    'root_tag_type': 'occasion',
#    'type': 'occasion'},
#   {'display_name': 'Big Batch',
#    'id': 65851,
#    'name': 'big_batch',
#    'parent_tag_name': 'cooking_style',
#    'root_tag_type': 'cooking_style',
#    'type': 'cooking_style'},
#   {'display_name': 'Pan Fry',
#    'id': 65859,
#    'name': 'pan_fry',
#    'parent_tag_name': 'cooking_style',
#    'root_tag_type': 'cooking_style',
#    'type': 'cooking_style'},
#   {'display_name': 'Bread Pan',
#    'id': 1247767,
#    'name': 'bread_pan',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Colander',
#    'id': 1247770,
#    'name': 'colander',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Ice Cream Scoop',
#    'id': 1247772,
#    'name': 'ice_cream_scoop',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Lollipop Sticks',
#    'id': 1247774,
#    'name': 'lollipop_sticks',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Paper Plates',
#    'id': 1247779,
#    'name': 'paper_plates',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Peeler',
#    'id': 1247781,
#    'name': 'peeler',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Pyrex',
#    'id': 1247785,
#    'name': 'pyrex',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Sauce Pan',
#    'id': 1247786,
#    'name': 'sauce_pan',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Whisk',
#    'id': 1247793,
#    'name': 'whisk',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Wooden Spoon',
#    'id': 1247794,
#    'name': 'wooden_spoon',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Zipper Freezer Bags',
#    'id': 1247795,
#    'name': 'zipper_freezer_bags',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Cooling Rack',
#    'id': 1280502,
#    'name': 'cooling_rack',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Holiday Cookie: How To',
#    'id': 3527978,
#    'name': 'holiday_cookie_howto',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Pescatarian',
#    'id': 3801552,
#    'name': 'pescatarian',
#    'parent_tag_name': 'dietary',
#    'root_tag_type': 'dietary',
#    'type': 'dietary'},
#   {'display_name': 'Caribbean',
#    'id': 3801554,
#    'name': 'caribbean',
#    'parent_tag_name': 'cuisine',
#    'root_tag_type': 'cuisine',
#    'type': 'cuisine'},
#   {'display_name': 'Black History Month',
#    'id': 3802076,
#    'name': 'black_history_month',
#    'parent_tag_name': None,
#    'root_tag_type': 'holiday',
#    'type': 'holiday'},
#   {'display_name': 'Asian Pacific American Heritage Month',
#    'id': 3802077,
#    'name': 'asian_pacific_american_heritage_month',
#    'parent_tag_name': None,
#    'root_tag_type': 'holiday',
#    'type': 'holiday'},
#   {'display_name': 'Almond Joy',
#    'id': 6361699,
#    'name': 'almond_joy',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Lil Brut',
#    'id': 6361775,
#    'name': 'lil_brut',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Tasty Holiday: Snacks',
#    'id': 6433722,
#    'name': 'tasty_holiday_snacks',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'NYNM Protein',
#    'id': 6543464,
#    'name': 'nynm_protein',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'NYNM Meal Prep',
#    'id': 6543466,
#    'name': 'nynm_meal_prep',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'MC Breakfast Savory',
#    'id': 6683351,
#    'name': 'mc_breakfast_savory',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Passover',
#    'id': 6742797,
#    'name': 'passover',
#    'parent_tag_name': 'holidays',
#    'root_tag_type': 'seasonal',
#    'type': 'holidays'},
#   {'display_name': 'Air Fryer',
#    'id': 6931167,
#    'name': 'air_fryer',
#    'parent_tag_name': 'appliance',
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'Filipino',
#    'id': 6953008,
#    'name': 'filipino',
#    'parent_tag_name': 'asian',
#    'root_tag_type': 'cuisine',
#    'type': 'asian'},
#   {'display_name': 'Taiwanese',
#    'id': 6953039,
#    'name': 'taiwanese',
#    'parent_tag_name': 'asian',
#    'root_tag_type': 'cuisine',
#    'type': 'asian'},
#   {'display_name': 'Swedish',
#    'id': 6953040,
#    'name': 'swedish',
#    'parent_tag_name': 'european',
#    'root_tag_type': 'cuisine',
#    'type': 'european'},
#   {'display_name': 'Lebanese',
#    'id': 6953043,
#    'name': 'lebanese',
#    'parent_tag_name': 'middle_eastern',
#    'root_tag_type': 'cuisine',
#    'type': 'middle_eastern'},
#   {'display_name': 'McCormick UGC One Pot Slow',
#    'id': 6986106,
#    'name': 'mccormick_ugc_one_pot_slow',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Fourth Eat',
#    'id': 7041337,
#    'name': 'fourth_eat',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Uber Game Day Dips',
#    'id': 7436545,
#    'name': 'uber_game_day_dips',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Live Jasmine and Tucker',
#    'id': 7560081,
#    'name': 'live_jasmine_and_tucker',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Shoppable Recipes Holiday Appetizers',
#    'id': 7608068,
#    'name': 'shoppable_recipes_holiday_appetizers',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Franks Handheld Bites',
#    'id': 7723151,
#    'name': 'franks_handheld_bites',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Butterfinger Runner Up Cookies',
#    'id': 7783332,
#    'name': 'butterfinger_runner_up_cookies',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Charcuterie Tips',
#    'id': 7987315,
#    'name': 'charcuterie_tips',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Charcuterie Breakfast',
#    'id': 8030032,
#    'name': 'charcuterie_breakfast',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Low-Calorie',
#    'id': 8091916,
#    'name': 'low_calorie',
#    'parent_tag_name': 'healthy',
#    'root_tag_type': 'healthy',
#    'type': 'healthy'},
#   {'display_name': 'High-Fiber',
#    'id': 8091920,
#    'name': 'high_fiber',
#    'parent_tag_name': 'healthy',
#    'root_tag_type': 'healthy',
#    'type': 'healthy'},
#   {'display_name': 'Red',
#    'id': 8322950,
#    'name': 'red',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Dole Crowd Pleasers',
#    'id': 8600869,
#    'name': 'dole_crowd_pleasers',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'McCormick Holiday Drinks',
#    'id': 8683061,
#    'name': 'mccormick_holiday_drinks',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Kings Hawaiian Delectable Dips',
#    'id': 8860914,
#    'name': 'kings_hawaiian_delectable_dips',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'South Africa African Cuisine',
#    'id': 8875017,
#    'name': 'south_africa_african_cuisine',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Incredible Egg Lunches',
#    'id': 8907402,
#    'name': 'incredible_egg_lunches',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Country Crock Apps',
#    'id': 9104328,
#    'name': 'country_crock_apps',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Asian',
#    'id': 9295873,
#    'name': 'asian',
#    'parent_tag_name': 'cuisine',
#    'root_tag_type': 'cuisine',
#    'type': 'cuisine'},
#   {'display_name': 'European',
#    'id': 9295874,
#    'name': 'european',
#    'parent_tag_name': 'cuisine',
#    'root_tag_type': 'cuisine',
#    'type': 'cuisine'},
#   {'display_name': 'Holidays',
#    'id': 9299130,
#    'name': 'holidays',
#    'parent_tag_name': 'seasonal',
#    'root_tag_type': 'seasonal',
#    'type': 'seasonal'},
#   {'display_name': 'Occasion',
#    'id': 9299134,
#    'name': 'occasion',
#    'parent_tag_name': 'seasonal',
#    'root_tag_type': 'seasonal',
#    'type': 'seasonal'},
#   {'display_name': 'Southern',
#    'id': 9299354,
#    'name': 'southern',
#    'parent_tag_name': 'north_american',
#    'root_tag_type': 'cuisine',
#    'type': 'north_american'},
#   {'display_name': 'Bread',
#    'id': 9299362,
#    'name': 'bread',
#    'parent_tag_name': 'baking',
#    'root_tag_type': 'appliance',
#    'type': 'baking'},
#   {'display_name': 'Sweet Breakfasts',
#    'id': 9299364,
#    'name': 'sweet_breakfasts',
#    'parent_tag_name': 'breakfast',
#    'root_tag_type': 'meal',
#    'type': 'breakfast'},
#   {'display_name': 'Egg Breakfasts',
#    'id': 9299366,
#    'name': 'egg_breakfasts',
#    'parent_tag_name': 'breakfast',
#    'root_tag_type': 'meal',
#    'type': 'breakfast'},
#   {'display_name': 'Coleslaws',
#    'id': 9299497,
#    'name': 'coleslaws',
#    'parent_tag_name': 'salads',
#    'root_tag_type': 'meal',
#    'type': 'salads'},
#   {'display_name': 'Beef',
#    'id': 9299515,
#    'name': 'beef',
#    'parent_tag_name': 'dinner',
#    'root_tag_type': 'meal',
#    'type': 'dinner'},
#   {'display_name': 'Stews',
#    'id': 9299527,
#    'name': 'stews',
#    'parent_tag_name': 'dinner',
#    'root_tag_type': 'meal',
#    'type': 'dinner'},
#   {'display_name': 'Stir Fry',
#    'id': 9299528,
#    'name': 'stir_fry',
#    'parent_tag_name': 'dinner',
#    'root_tag_type': 'meal',
#    'type': 'dinner'},
#   {'display_name': 'Lasagna',
#    'id': 9299622,
#    'name': 'lasagna',
#    'parent_tag_name': 'pasta',
#    'root_tag_type': 'meal',
#    'type': 'pasta'},
#   {'display_name': 'Macaroni & Cheese',
#    'id': 9299623,
#    'name': 'macaroni_cheese',
#    'parent_tag_name': 'pasta',
#    'root_tag_type': 'meal',
#    'type': 'pasta'},
#   {'display_name': 'Fish',
#    'id': 9299649,
#    'name': 'fish',
#    'parent_tag_name': 'seafood',
#    'root_tag_type': 'meal',
#    'type': 'seafood'},
#   {'display_name': 'Pie and Cobblers',
#    'id': 9299680,
#    'name': 'pie_and_cobblers',
#    'parent_tag_name': 'desserts',
#    'root_tag_type': 'meal',
#    'type': 'desserts'},
#   {'display_name': 'Puddings',
#    'id': 9299684,
#    'name': 'puddings',
#    'parent_tag_name': 'desserts',
#    'root_tag_type': 'meal',
#    'type': 'desserts'},
#   {'display_name': 'Gin',
#    'id': 9299793,
#    'name': 'gin',
#    'parent_tag_name': 'cocktails',
#    'root_tag_type': 'meal',
#    'type': 'cocktails'},
#   {'display_name': 'Kings Hawaiian Pizza',
#    'id': 10032069,
#    'name': 'kings_hawaiian_pizza',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'cozy_fall_fare',
#    'id': 10080871,
#    'name': 'cozy_fall_fare',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Shoppable Sides',
#    'id': 10219605,
#    'name': 'shoppable_sides',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'zelle_pandan',
#    'id': 10274841,
#    'name': 'zelle_pandan',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'zelle_scallion_pork',
#    'id': 10274842,
#    'name': 'zelle_scallion_pork',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Holiday Drinks',
#    'id': 10296625,
#    'name': 'holiday_drinks',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Decadent Dinners',
#    'id': 10315444,
#    'name': 'decadent_dinners',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Seafood',
#    'id': 10623610,
#    'name': 'seafood',
#    'parent_tag_name': 'ingredients_to_avoid',
#    'root_tag_type': 'ingredients_to_avoid',
#    'type': 'ingredients_to_avoid'},
#   {'display_name': 'Kosher',
#    'id': 10742775,
#    'name': 'kosher',
#    'parent_tag_name': 'dietary',
#    'root_tag_type': 'dietary',
#    'type': 'dietary'},
#   {'display_name': 'KH Sweets',
#    'id': 11024933,
#    'name': 'kh_sweets',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Cap One Sips',
#    'id': 11173650,
#    'name': 'cap_one_sips',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'National Sandwich Day',
#    'id': 11176535,
#    'name': 'national_sandwich_day',
#    'parent_tag_name': 'breakfast',
#    'root_tag_type': 'meal',
#    'type': 'breakfast'},
#   {'display_name': 'Brittany',
#    'id': 11230772,
#    'name': 'brittany',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Ivanna',
#    'id': 11230775,
#    'name': 'ivanna',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Katie',
#    'id': 11230776,
#    'name': 'katie',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Mediterranean',
#    'id': 64451,
#    'name': 'mediterranean',
#    'parent_tag_name': 'european',
#    'root_tag_type': 'cuisine',
#    'type': 'european'},
#   {'display_name': 'Japanese',
#    'id': 64454,
#    'name': 'japanese',
#    'parent_tag_name': 'asian',
#    'root_tag_type': 'cuisine',
#    'type': 'asian'},
#   {'display_name': 'Korean',
#    'id': 64455,
#    'name': 'korean',
#    'parent_tag_name': 'asian',
#    'root_tag_type': 'cuisine',
#    'type': 'asian'},
#   {'display_name': 'Dairy-Free',
#    'id': 64463,
#    'name': 'dairy_free',
#    'parent_tag_name': 'dietary',
#    'root_tag_type': 'dietary',
#    'type': 'dietary'},
#   {'display_name': 'Appetizers',
#    'id': 64481,
#    'name': 'appetizers',
#    'parent_tag_name': 'meal',
#    'root_tag_type': 'meal',
#    'type': 'meal'},
#   {'display_name': 'Brunch',
#    'id': 64484,
#    'name': 'brunch',
#    'parent_tag_name': 'meal',
#    'root_tag_type': 'meal',
#    'type': 'meal'},
#   {'display_name': 'Desserts',
#    'id': 64485,
#    'name': 'desserts',
#    'parent_tag_name': 'meal',
#    'root_tag_type': 'meal',
#    'type': 'meal'},
#   {'display_name': 'Drinks',
#    'id': 64487,
#    'name': 'drinks',
#    'parent_tag_name': 'meal',
#    'root_tag_type': 'meal',
#    'type': 'meal'},
#   {'display_name': 'Lunch',
#    'id': 64489,
#    'name': 'lunch',
#    'parent_tag_name': 'meal',
#    'root_tag_type': 'meal',
#    'type': 'meal'},
#   {'display_name': 'Deep-Fry',
#    'id': 64493,
#    'name': 'deep_fry',
#    'parent_tag_name': 'cooking_style',
#    'root_tag_type': 'cooking_style',
#    'type': 'cooking_style'},
#   {'display_name': 'Date Night',
#    'id': 64500,
#    'name': 'date_night',
#    'parent_tag_name': 'occasion',
#    'root_tag_type': 'seasonal',
#    'type': 'occasion'},
#   {'display_name': 'Special Occasion',
#    'id': 188967,
#    'name': 'special_occasion',
#    'parent_tag_name': 'occasion',
#    'root_tag_type': 'seasonal',
#    'type': 'occasion'},
#   {'display_name': 'Cake Pan',
#    'id': 1247768,
#    'name': 'cake_pan',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Cheese Grater',
#    'id': 1247769,
#    'name': 'cheese_grater',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Oven Mitts',
#    'id': 1247775,
#    'name': 'oven_mitts',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Paper Bowls',
#    'id': 1247776,
#    'name': 'paper_bowls',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Paper Cups',
#    'id': 1247777,
#    'name': 'paper_cups',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Saute Pan',
#    'id': 1247787,
#    'name': 'saute_pan',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Strainer',
#    'id': 1247789,
#    'name': 'strainer',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Tongs',
#    'id': 1247790,
#    'name': 'tongs',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Zipper Storage Bags',
#    'id': 1247796,
#    'name': 'zipper_storage_bags',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Baking Cups',
#    'id': 1280499,
#    'name': 'baking_cups',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Mixing Bowl',
#    'id': 1280510,
#    'name': 'mixing_bowl',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'One Top Friendly',
#    'id': 1691103,
#    'name': 'one_top_friendly',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Holiday Cookie: Recipe',
#    'id': 3527977,
#    'name': 'holiday_cookie_recipe',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Holiday Cookie: Hacks',
#    'id': 3527979,
#    'name': 'holiday_cookie_hacks',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'McCormick Easy Dinner',
#    'id': 5143247,
#    'name': 'mccormick_easy_dinner',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Quarantine Cooking: Recipe',
#    'id': 5812430,
#    'name': 'qfp_recipes',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Eko Video',
#    'id': 5831533,
#    'name': 'eko_video',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Best of Tasty',
#    'id': 5831534,
#    'name': 'best_of_tasty',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': "Tasty's 5th Birthday: Savory",
#    'id': 5993379,
#    'name': 'tasty_s_5th_birthday_savory',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tasty EWD Family',
#    'id': 6117477,
#    'name': 'tasty_ewd_family',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Every Occasion',
#    'id': 6143339,
#    'name': 'every_occasion',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': '3 Musketeers',
#    'id': 6361701,
#    'name': '3_musketeers',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'For Real Grapefruit',
#    'id': 6361774,
#    'name': 'for_real_grapefruit',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Tasty Dinner Kits',
#    'id': 6361812,
#    'name': 'tasty_dinner_kits',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Tasty Holiday: Thanksgiving',
#    'id': 6389771,
#    'name': 'tasty_holiday_thanksgiving',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tasty Holiday: Christmas',
#    'id': 6389772,
#    'name': 'tasty_holiday_christmas',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tasty Holiday: Festive Favorites',
#    'id': 6389775,
#    'name': 'tasty_holiday_festive_favorites',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': "Frank's Vegetarian Snacks",
#    'id': 6477325,
#    'name': 'frank_s_vegetarian_snacks',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'NYNM Expert',
#    'id': 6543462,
#    'name': 'nynm_expert',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Lunar New Year',
#    'id': 6573766,
#    'name': 'lunar_new_year',
#    'parent_tag_name': 'holidays',
#    'root_tag_type': 'seasonal',
#    'type': 'holidays'},
#   {'display_name': 'MC Breakfast Sweet',
#    'id': 6683350,
#    'name': 'mc_breakfast_sweet',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'MC Breakfast Healthy',
#    'id': 6683352,
#    'name': 'mc_breakfast_healthy',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': "St. Patrick's Day",
#    'id': 6711300,
#    'name': 'st_patrick_s_day',
#    'parent_tag_name': 'holidays',
#    'root_tag_type': 'seasonal',
#    'type': 'holidays'},
#   {'display_name': 'Spring Drink',
#    'id': 6718870,
#    'name': 'spring_drink',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Spring Holiday',
#    'id': 6718874,
#    'name': 'spring_holiday',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Budget Four',
#    'id': 6830252,
#    'name': 'budget_four',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Cinco de Mayo',
#    'id': 6854261,
#    'name': 'cinco_de_mayo',
#    'parent_tag_name': 'holidays',
#    'root_tag_type': 'seasonal',
#    'type': 'holidays'},
#   {'display_name': "Mother's Day",
#    'id': 6854262,
#    'name': 'mothers_day',
#    'parent_tag_name': 'holidays',
#    'root_tag_type': 'seasonal',
#    'type': 'holidays'},
#   {'display_name': 'Laotian',
#    'id': 6953046,
#    'name': 'laotian',
#    'parent_tag_name': 'asian',
#    'root_tag_type': 'cuisine',
#    'type': 'asian'},
#   {'display_name': 'Cuban',
#    'id': 6953048,
#    'name': 'cuban',
#    'parent_tag_name': 'caribbean',
#    'root_tag_type': 'cuisine',
#    'type': 'caribbean'},
#   {'display_name': 'Venezuelan',
#    'id': 6953052,
#    'name': 'venezuelan',
#    'parent_tag_name': 'central_south_american',
#    'root_tag_type': 'cuisine',
#    'type': 'central_south_american'},
#   {'display_name': 'McCormick UGC One Pot Winners',
#    'id': 6986104,
#    'name': 'mccormick_ugc_one_pot_winners',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Summer Eat',
#    'id': 7041320,
#    'name': 'summer_eat',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Summer Sides',
#    'id': 7041323,
#    'name': 'summer_sides',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Fourth Drink',
#    'id': 7041338,
#    'name': 'fourth_drink',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Latinx Heritage Month',
#    'id': 7145248,
#    'name': 'latinx_heritage_month',
#    'parent_tag_name': None,
#    'root_tag_type': 'holiday',
#    'type': 'holiday'},
#   {'display_name': 'Uber Game Day Appetizers',
#    'id': 7436544,
#    'name': 'uber_game_day_appetizers',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Thanksgiving Desserts',
#    'id': 7510771,
#    'name': 'thanksgiving_desserts',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Thanksgiving Sips',
#    'id': 7510772,
#    'name': 'thanksgiving_sips',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Shoppable Recipes Holiday Dinners',
#    'id': 7559500,
#    'name': 'shoppable_recipes_holiday_dinners',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Charcuterie Sweetchuterie',
#    'id': 8030030,
#    'name': 'charcuterie_sweetchuterie',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Charcuterie Appetizers',
#    'id': 8030031,
#    'name': 'charcuterie_appetizers',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Under 45 Minutes',
#    'id': 8091747,
#    'name': 'under_45_minutes',
#    'parent_tag_name': 'difficulty',
#    'root_tag_type': 'difficulty',
#    'type': 'difficulty'},
#   {'display_name': 'McCormick World Hearty',
#    'id': 8104111,
#    'name': 'mccormick_world_hearty',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'McCormick World Desserts',
#    'id': 8104113,
#    'name': 'mccormick_world_desserts',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Juneteenth',
#    'id': 8227134,
#    'name': 'juneteenth',
#    'parent_tag_name': None,
#    'root_tag_type': 'holiday',
#    'type': 'holiday'},
#   {'display_name': 'Pink',
#    'id': 8322951,
#    'name': 'pink',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Dole Hearty Meals',
#    'id': 8719451,
#    'name': 'dole_hearty_meals',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Ghana African Cuisine',
#    'id': 8874994,
#    'name': 'ghana_african_cuisine',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Kenya African Cuisine',
#    'id': 8875005,
#    'name': 'kenya_african_cuisine',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Haiti African Cuisine',
#    'id': 8875006,
#    'name': 'haiti_african_cuisine',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Trinidad African Cuisine',
#    'id': 8875007,
#    'name': 'trinidad_african_cuisine',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'East Africa African Cuisine',
#    'id': 8875016,
#    'name': 'east_africa_african_cuisine',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Country Crock Desserts',
#    'id': 9104326,
#    'name': 'country_crock_desserts',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Country Crock Veggies',
#    'id': 9104329,
#    'name': 'country_crock_veggies',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Cooking Style',
#    'id': 9295810,
#    'name': 'cooking_style',
#    'parent_tag_name': None,
#    'root_tag_type': 'cooking_style',
#    'type': 'cooking_style'},
#   {'display_name': 'Meal',
#    'id': 9295813,
#    'name': 'meal',
#    'parent_tag_name': None,
#    'root_tag_type': 'meal',
#    'type': 'meal'},
#   {'display_name': 'Difficulty',
#    'id': 9295816,
#    'name': 'difficulty',
#    'parent_tag_name': None,
#    'root_tag_type': 'difficulty',
#    'type': 'difficulty'},
#   {'display_name': 'Picnic',
#    'id': 9299360,
#    'name': 'picnic',
#    'parent_tag_name': 'occasion',
#    'root_tag_type': 'seasonal',
#    'type': 'occasion'},
#   {'display_name': 'New Years',
#    'id': 9299361,
#    'name': 'new_years',
#    'parent_tag_name': 'holidays',
#    'root_tag_type': 'seasonal',
#    'type': 'holidays'},
#   {'display_name': 'Smoothies & Smoothie Bowls',
#    'id': 9299368,
#    'name': 'smoothies_smoothie_bowls',
#    'parent_tag_name': 'breakfast',
#    'root_tag_type': 'meal',
#    'type': 'breakfast'},
#   {'display_name': 'Pancakes',
#    'id': 9299397,
#    'name': 'pancakes',
#    'parent_tag_name': 'sweet_breakfasts',
#    'root_tag_type': 'meal',
#    'type': 'sweet_breakfasts'},
#   {'display_name': 'Salads',
#    'id': 9299495,
#    'name': 'salads',
#    'parent_tag_name': 'lunch',
#    'root_tag_type': 'meal',
#    'type': 'lunch'},
#   {'display_name': 'Dressings',
#    'id': 9299512,
#    'name': 'dressings',
#    'parent_tag_name': 'salads',
#    'root_tag_type': 'meal',
#    'type': 'salads'},
#   {'display_name': 'Pork',
#    'id': 9299516,
#    'name': 'pork',
#    'parent_tag_name': 'dinner',
#    'root_tag_type': 'meal',
#    'type': 'dinner'},
#   {'display_name': 'Pot Roast',
#    'id': 9299524,
#    'name': 'pot_roast',
#    'parent_tag_name': 'dinner',
#    'root_tag_type': 'meal',
#    'type': 'dinner'},
#   {'display_name': 'Soups',
#    'id': 9299526,
#    'name': 'soups',
#    'parent_tag_name': 'dinner',
#    'root_tag_type': 'meal',
#    'type': 'dinner'},
#   {'display_name': 'Cupcakes',
#    'id': 9299686,
#    'name': 'cupcakes',
#    'parent_tag_name': 'cakes',
#    'root_tag_type': 'meal',
#    'type': 'cakes'},
#   {'display_name': 'Ice Cream Cakes',
#    'id': 9299687,
#    'name': 'ice_cream_cakes',
#    'parent_tag_name': 'ice_cream',
#    'root_tag_type': 'meal',
#    'type': 'ice_cream'},
#   {'display_name': 'Rum',
#    'id': 9299797,
#    'name': 'rum',
#    'parent_tag_name': 'cocktails',
#    'root_tag_type': 'meal',
#    'type': 'cocktails'},
#   {'display_name': 'Kings Hawaiian On the Grill',
#    'id': 9345545,
#    'name': 'kings_hawaiian_on_the_grill',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Kings Hawaiian Perfect Sides',
#    'id': 9345546,
#    'name': 'kings_hawaiian_perfect_sides',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Kings Hawaiian Nachos',
#    'id': 10032068,
#    'name': 'kings_hawaiian_nachos',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Kings Hawaiian Dips',
#    'id': 10032071,
#    'name': 'kings_hawaiian_dips',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'ghoulishly_good_desserts',
#    'id': 10080870,
#    'name': 'ghoulishly_good_desserts',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Walmart Meal Planning October',
#    'id': 10089785,
#    'name': 'walmart_meal_planning_october',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Shoppable Sips',
#    'id': 10219607,
#    'name': 'shoppable_sips',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'zelle_matcha_sesame',
#    'id': 10274844,
#    'name': 'zelle_matcha_sesame',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Holiday Mains',
#    'id': 10296624,
#    'name': 'holiday_mains',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Slow Cooker Scores',
#    'id': 10315445,
#    'name': 'slow_cooker_scores',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Soy',
#    'id': 10623590,
#    'name': 'soy',
#    'parent_tag_name': 'ingredients_to_avoid',
#    'root_tag_type': 'ingredients_to_avoid',
#    'type': 'ingredients_to_avoid'},
#   {'display_name': 'Tree nuts',
#    'id': 10640006,
#    'name': 'tree_nuts',
#    'parent_tag_name': 'ingredients_to_avoid',
#    'root_tag_type': 'ingredients_to_avoid',
#    'type': 'ingredients_to_avoid'},
#   {'display_name': 'Tillamook Chicken',
#    'id': 10912079,
#    'name': 'tillamook_chicken',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'KH Cheesy Delights',
#    'id': 11024936,
#    'name': 'kh_cheesy_delights',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Thomas Meal Planning 4',
#    'id': 11085392,
#    'name': 'thomas_meal_planning_4',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Kelly',
#    'id': 11230778,
#    'name': 'kelly',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Brazilian',
#    'id': 64446,
#    'name': 'brazilian',
#    'parent_tag_name': 'central_south_american',
#    'root_tag_type': 'cuisine',
#    'type': 'central_south_american'},
#   {'display_name': 'British',
#    'id': 64447,
#    'name': 'british',
#    'parent_tag_name': 'european',
#    'root_tag_type': 'cuisine',
#    'type': 'european'},
#   {'display_name': 'Chinese',
#    'id': 64448,
#    'name': 'chinese',
#    'parent_tag_name': 'asian',
#    'root_tag_type': 'cuisine',
#    'type': 'asian'},
#   {'display_name': 'German',
#    'id': 64450,
#    'name': 'german',
#    'parent_tag_name': 'european',
#    'root_tag_type': 'cuisine',
#    'type': 'european'},
#   {'display_name': 'Indian',
#    'id': 64452,
#    'name': 'indian',
#    'parent_tag_name': 'asian',
#    'root_tag_type': 'cuisine',
#    'type': 'asian'},
#   {'display_name': 'Mexican',
#    'id': 64457,
#    'name': 'mexican',
#    'parent_tag_name': 'north_american',
#    'root_tag_type': 'cuisine',
#    'type': 'north_american'},
#   {'display_name': 'Seafood',
#    'id': 64459,
#    'name': 'seafood',
#    'parent_tag_name': 'dinner',
#    'root_tag_type': 'meal',
#    'type': 'dinner'},
#   {'display_name': 'Comfort Food',
#    'id': 64462,
#    'name': 'comfort_food',
#    'parent_tag_name': 'cooking_style',
#    'root_tag_type': 'cooking_style',
#    'type': 'cooking_style'},
#   {'display_name': 'Vegan',
#    'id': 64468,
#    'name': 'vegan',
#    'parent_tag_name': 'dietary',
#    'root_tag_type': 'dietary',
#    'type': 'dietary'},
#   {'display_name': '5 Ingredients or Less',
#    'id': 64470,
#    'name': '5_ingredients_or_less',
#    'parent_tag_name': 'difficulty',
#    'root_tag_type': 'difficulty',
#    'type': 'difficulty'},
#   {'display_name': '4th of July',
#    'id': 64475,
#    'name': '4th_of_july',
#    'parent_tag_name': 'holidays',
#    'root_tag_type': 'seasonal',
#    'type': 'holidays'},
#   {'display_name': 'Baking',
#    'id': 64492,
#    'name': 'baking',
#    'parent_tag_name': 'appliance',
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'Spring',
#    'id': 64509,
#    'name': 'spring',
#    'parent_tag_name': 'seasonal',
#    'root_tag_type': 'seasonal',
#    'type': 'seasonal'},
#   {'display_name': 'Winter',
#    'id': 64511,
#    'name': 'winter',
#    'parent_tag_name': 'seasonal',
#    'root_tag_type': 'seasonal',
#    'type': 'seasonal'},
#   {'display_name': 'Broiler',
#    'id': 65839,
#    'name': 'broiler',
#    'parent_tag_name': 'appliance',
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'Cast Iron Pan',
#    'id': 65840,
#    'name': 'cast_iron_pan',
#    'parent_tag_name': 'appliance',
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'Slow Cooker',
#    'id': 65847,
#    'name': 'slow_cooker',
#    'parent_tag_name': 'appliance',
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'Wok',
#    'id': 65849,
#    'name': 'wok',
#    'parent_tag_name': 'appliance',
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'Mashup',
#    'id': 65852,
#    'name': 'mashup',
#    'parent_tag_name': None,
#    'root_tag_type': 'cooking_style',
#    'type': 'cooking_style'},
#   {'display_name': 'No Bake Desserts',
#    'id': 65854,
#    'name': 'no_bake_desserts',
#    'parent_tag_name': 'cooking_style',
#    'root_tag_type': 'cooking_style',
#    'type': 'cooking_style'},
#   {'display_name': 'Paper Napkins',
#    'id': 1247778,
#    'name': 'paper_napkins',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Parchment Paper',
#    'id': 1247780,
#    'name': 'parchment_paper',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Wax Paper',
#    'id': 1247792,
#    'name': 'wax_paper',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Cooking Kit',
#    'id': 1280498,
#    'name': 'cooking_kit',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Liquid Measuring Cup',
#    'id': 1280506,
#    'name': 'liquid_measuring_cup',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Dry Measuring Cups',
#    'id': 1280507,
#    'name': 'dry_measuring_cups',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Rolling Pin',
#    'id': 1280512,
#    'name': 'rolling_pin',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Spider',
#    'id': 1280514,
#    'name': 'spider',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Main Feed',
#    'id': 2651752,
#    'name': 'one_top_app_main_feed',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Veggies',
#    'id': 2651756,
#    'name': 'one_top_app_veggies',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Sides',
#    'id': 2651757,
#    'name': 'one_top_app_sides',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Steak',
#    'id': 2651761,
#    'name': 'one_top_app_steak',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Ice Cream Social',
#    'id': 3801551,
#    'name': 'ice_cream_social',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Pride Month',
#    'id': 3802078,
#    'name': 'pride_month',
#    'parent_tag_name': None,
#    'root_tag_type': 'holiday',
#    'type': 'holiday'},
#   {'display_name': 'Sponsored Recipe',
#    'id': 4202175,
#    'name': 'sponsored_recipe',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Beyond Red Blend',
#    'id': 5923246,
#    'name': 'beyond_red_blend',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Oh So Rosé',
#    'id': 5923247,
#    'name': 'oh_so_rose',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Tasty EWD Healthy',
#    'id': 6117476,
#    'name': 'tasty_ewd_healthy',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tasty EWD Fall',
#    'id': 6117478,
#    'name': 'tasty_ewd_fall',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tasty EWD Fifteen',
#    'id': 6117479,
#    'name': 'tasty_ewd_fifteen',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Walmart Plus Holiday 2020',
#    'id': 6207870,
#    'name': 'walmart_plus_holiday_2020',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Snickers',
#    'id': 6361700,
#    'name': 'snickers',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': "Hershey's",
#    'id': 6361740,
#    'name': 'hershey_s',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Peppermint Pattie',
#    'id': 6361741,
#    'name': 'peppermint_pattie',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Deeply Blood Orange',
#    'id': 6361773,
#    'name': 'deeply_blood_orange',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Raspberry Rosé',
#    'id': 6361809,
#    'name': 'raspberry_rose',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': "Frank's Cheesy Apps",
#    'id': 6477317,
#    'name': 'frank_s_cheesy_apps',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tips Basics',
#    'id': 6718864,
#    'name': 'tips_basics',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tips Pros',
#    'id': 6718866,
#    'name': 'tips_pros',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tips Culinary',
#    'id': 6718868,
#    'name': 'tips_culinary',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Spring Kitchen',
#    'id': 6718876,
#    'name': 'spring_kitchen',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tasty EWD Comfort',
#    'id': 6807663,
#    'name': 'tasty_ewd_comfort',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Budget 10',
#    'id': 6830248,
#    'name': 'budget_10',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Budget Shop',
#    'id': 6830251,
#    'name': 'budget_shop',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Hawaiian',
#    'id': 6953012,
#    'name': 'hawaiian',
#    'parent_tag_name': 'north_american',
#    'root_tag_type': 'cuisine',
#    'type': 'north_american'},
#   {'display_name': 'Dominican',
#    'id': 6953047,
#    'name': 'dominican',
#    'parent_tag_name': 'caribbean',
#    'root_tag_type': 'cuisine',
#    'type': 'caribbean'},
#   {'display_name': 'Puerto Rican',
#    'id': 6953050,
#    'name': 'puerto_rican',
#    'parent_tag_name': 'caribbean',
#    'root_tag_type': 'cuisine',
#    'type': 'caribbean'},
#   {'display_name': 'Summer Drink',
#    'id': 7041321,
#    'name': 'summer_drink',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Summer Holiday',
#    'id': 7041322,
#    'name': 'summer_holiday',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Summer Desserts',
#    'id': 7041324,
#    'name': 'summer_desserts',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Shoppable Recipes Meal Prep',
#    'id': 7336055,
#    'name': 'shoppable_recipes_meal_prep',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Thanksgiving Classics',
#    'id': 7510744,
#    'name': 'thanksgiving_classics',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Thanksgiving Slow',
#    'id': 7510780,
#    'name': 'thanksgiving_slow',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Shoppable Recipes Seasonal Desserts',
#    'id': 7559501,
#    'name': 'shoppable_recipes_seasonal_desserts',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Live Upcoming',
#    'id': 7584483,
#    'name': 'live_upcoming',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Franks Spicy Bites',
#    'id': 7723148,
#    'name': 'franks_spicy_bites',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Butterfinger Runner Up Bark',
#    'id': 7783333,
#    'name': 'butterfinger_runner_up_bark',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Butterfinger Other Recipes',
#    'id': 7783334,
#    'name': 'butterfinger_other_recipes',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Charcuterie Recipes',
#    'id': 7987316,
#    'name': 'charcuterie_recipes',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tasty Charcuterie Quizzes',
#    'id': 8029893,
#    'name': 'tasty_charcuterie_quizzes',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
# ...
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Baking Kit',
#    'id': 1280497,
#    'name': 'baking_kit',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': "Chef's Knife",
#    'id': 1280501,
#    'name': 'chefs_knife',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Fish Spatula',
#    'id': 1280504,
#    'name': 'fish_spatula',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Kitchen Shears',
#    'id': 1280505,
#    'name': 'kitchen_shears',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Measuring Spoons',
#    'id': 1280508,
#    'name': 'measuring_spoons',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Microplane',
#    'id': 1280509,
#    'name': 'microplane',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Sieve',
#    'id': 1280513,
#    'name': 'sieve',
#    'parent_tag_name': None,
#    'root_tag_type': 'equipment',
#    'type': 'equipment'},
#   {'display_name': 'Epoca-Walmart',
#    'id': 1691104,
#    'name': 'epoca_walmart',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Eggs',
#    'id': 2651754,
#    'name': 'one_top_app_eggs',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Dessert',
#    'id': 2651758,
#    'name': 'one_top_app_dessert',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Grains',
#    'id': 2651759,
#    'name': 'one_top_app_grains',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Chop Champ',
#    'id': 3028912,
#    'name': 'chop_champ',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Pressure Cooker',
#    'id': 4767335,
#    'name': 'pressure_cooker',
#    'parent_tag_name': None,
#    'root_tag_type': 'appliance',
#    'type': 'appliance'},
#   {'display_name': 'tastyjunior',
#    'id': 4767341,
#    'name': 'tastyjunior',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'McCormick Game Day',
#    'id': 5143246,
#    'name': 'mccormick_game_day',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Quarantine Cooking: Baking',
#    'id': 5812431,
#    'name': 'qfp_baking',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Perf Pinot Noir',
#    'id': 6361777,
#    'name': 'perf_pinot_noir',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Sparkling Rosé',
#    'id': 6361810,
#    'name': 'sparkling_rose',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Tasty Holiday: Hanukkah',
#    'id': 6389773,
#    'name': 'tasty_holiday_hanukkah',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': "Frank's Chicken Bites",
#    'id': 6477316,
#    'name': 'frank_s_chicken_bites',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'NYNM Money',
#    'id': 6543442,
#    'name': 'nynm_money',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'NYNM Veggie',
#    'id': 6543461,
#    'name': 'nynm_veggie',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'NYNM Instant Pot',
#    'id': 6543463,
#    'name': 'nynm_instant_pot',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Tips Viral',
#    'id': 6718867,
#    'name': 'tips_viral',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Spring Eat',
#    'id': 6718869,
#    'name': 'spring_eat',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Spring Sides',
#    'id': 6718875,
#    'name': 'spring_sides',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Budget Expert',
#    'id': 6830250,
#    'name': 'budget_expert',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Ethiopian',
#    'id': 6953013,
#    'name': 'ethiopian',
#    'parent_tag_name': 'african',
#    'root_tag_type': 'cuisine',
#    'type': 'african'},
#   {'display_name': 'West African',
#    'id': 6953016,
#    'name': 'west_african',
#    'parent_tag_name': 'african',
#    'root_tag_type': 'cuisine',
#    'type': 'african'},
#   {'display_name': 'Peruvian',
#    'id': 6953044,
#    'name': 'peruvian',
#    'parent_tag_name': 'central_south_american',
#    'root_tag_type': 'cuisine',
#    'type': 'central_south_american'},
#   {'display_name': 'Indigenous',
#    'id': 6953045,
#    'name': 'indigenous',
#    'parent_tag_name': 'cuisine',
#    'root_tag_type': 'cuisine',
#    'type': 'cuisine'},
#   {'display_name': 'McCormick UGC One Pot Others',
#    'id': 6986107,
#    'name': 'mccormick_ugc_one_pot_others',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Shoppable Recipes Family Dinner',
#    'id': 7336056,
#    'name': 'shoppable_recipes_family_dinner',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Shoppable Recipes Desserts',
#    'id': 7336057,
#    'name': 'shoppable_recipes_desserts',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Shoppable Recipes Thanksgiving',
#    'id': 7559499,
#    'name': 'shoppable_recipes_thanksgiving',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Live Past Lives',
#    'id': 7560082,
#    'name': 'live_past_lives',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Franks Nachos',
#    'id': 7723149,
#    'name': 'franks_nachos',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Butterfinger Winner',
#    'id': 7783331,
#    'name': 'butterfinger_winner',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Under 15 Minutes',
#    'id': 8091744,
#    'name': 'under_15_minutes',
#    'parent_tag_name': 'difficulty',
#    'root_tag_type': 'difficulty',
#    'type': 'difficulty'},
#   {'display_name': 'Low-Fat',
#    'id': 8091919,
#    'name': 'low_fat',
#    'parent_tag_name': 'healthy',
#    'root_tag_type': 'healthy',
#    'type': 'healthy'},
#   {'display_name': 'McCormick World Sides',
#    'id': 8104110,
#    'name': 'mccormick_world_sides',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Blue',
#    'id': 8322949,
#    'name': 'blue',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Walmart Meal Planning',
#    'id': 8323092,
#    'name': 'walmart_meal_planning',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Dole Sweet Treats',
#    'id': 8600870,
#    'name': 'dole_sweet_treats',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'McCormick Holiday Mains',
#    'id': 8683064,
#    'name': 'mccormick_holiday_mains',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Dole Snacks',
#    'id': 8719450,
#    'name': 'dole_snacks',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Dole Desserts',
#    'id': 8719453,
#    'name': 'dole_desserts',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Cuisine',
#    'id': 8757513,
#    'name': 'cuisine',
#    'parent_tag_name': None,
#    'root_tag_type': 'cuisine',
#    'type': 'cuisine'},
#   {'display_name': 'Kings Hawaiian Roll Sliders',
#    'id': 8860912,
#    'name': 'kings_hawaiian_roll_sliders',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Kings Hawaiian Savory Wings',
#    'id': 8860913,
#    'name': 'kings_hawaiian_savory_wings',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Nigeria African Cuisine',
#    'id': 8874992,
#    'name': 'nigeria_african_cuisine',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Cuba African Cuisine',
#    'id': 8875008,
#    'name': 'cuba_african_cuisine',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'West Africa African Cuisine',
#    'id': 8875015,
#    'name': 'west_africa_african_cuisine',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Ooni Other',
#    'id': 9164155,
#    'name': 'ooni_other',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Polish',
#    'id': 9299304,
#    'name': 'polish',
#    'parent_tag_name': 'european',
#    'root_tag_type': 'cuisine',
#    'type': 'european'},
#   {'display_name': 'Chilis',
#    'id': 9299518,
#    'name': 'chilis',
#    'parent_tag_name': 'dinner',
#    'root_tag_type': 'meal',
#    'type': 'dinner'},
#   {'display_name': 'Pasta',
#    'id': 9299522,
#    'name': 'pasta',
#    'parent_tag_name': 'dinner',
#    'root_tag_type': 'meal',
#    'type': 'dinner'},
#   {'display_name': 'Cakes',
#    'id': 9299665,
#    'name': 'cakes',
#    'parent_tag_name': 'desserts',
#    'root_tag_type': 'meal',
#    'type': 'desserts'},
#   {'display_name': 'Ice Cream',
#    'id': 9299683,
#    'name': 'ice_cream',
#    'parent_tag_name': 'desserts',
#    'root_tag_type': 'meal',
#    'type': 'desserts'},
#   {'display_name': 'Cheesecakes',
#    'id': 9299685,
#    'name': 'cheesecakes',
#    'parent_tag_name': 'cakes',
#    'root_tag_type': 'meal',
#    'type': 'cakes'},
#   {'display_name': 'Ice Cream Sandwiches',
#    'id': 9299688,
#    'name': 'ice_cream_sandwiches',
#    'parent_tag_name': 'ice_cream',
#    'root_tag_type': 'meal',
#    'type': 'ice_cream'},
#   {'display_name': 'Vodka',
#    'id': 9299794,
#    'name': 'vodka',
#    'parent_tag_name': 'cocktails',
#    'root_tag_type': 'meal',
#    'type': 'cocktails'},
#   {'display_name': 'Whiskey',
#    'id': 9299795,
#    'name': 'whiskey',
#    'parent_tag_name': 'cocktails',
#    'root_tag_type': 'meal',
#    'type': 'cocktails'},
#   {'display_name': 'Juices',
#    'id': 9299833,
#    'name': 'juices',
#    'parent_tag_name': 'drinks',
#    'root_tag_type': 'meal',
#    'type': 'drinks'},
#   {'display_name': 'Walmart Meal Planning July',
#    'id': 9835858,
#    'name': 'walmart_meal_planning_july',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Walmart Meal Planning August',
#    'id': 9921873,
#    'name': 'walmart_meal_planning_august',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Kings Hawaiian Vegetarian',
#    'id': 10032070,
#    'name': 'kings_hawaiian_vegetarian',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'spine_chilling_savories',
#    'id': 10080869,
#    'name': 'spine_chilling_savories',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Shoppable Desserts',
#    'id': 10219606,
#    'name': 'shoppable_desserts',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'zelle_miso_brown_butter',
#    'id': 10274845,
#    'name': 'zelle_miso_brown_butter',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Chewy Cookies',
#    'id': 10296621,
#    'name': 'chewy_cookies',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Shellfish',
#    'id': 10623586,
#    'name': 'shellfish',
#    'parent_tag_name': 'ingredients_to_avoid',
#    'root_tag_type': 'ingredients_to_avoid',
#    'type': 'ingredients_to_avoid'},
#   {'display_name': 'Gluten',
#    'id': 10623589,
#    'name': 'gluten',
#    'parent_tag_name': 'ingredients_to_avoid',
#    'root_tag_type': 'ingredients_to_avoid',
#    'type': 'ingredients_to_avoid'},
#   {'display_name': 'Pork',
#    'id': 10623613,
#    'name': 'pork',
#    'parent_tag_name': 'ingredients_to_avoid',
#    'root_tag_type': 'ingredients_to_avoid',
#    'type': 'ingredients_to_avoid'},
#   {'display_name': 'Peanuts',
#    'id': 10640007,
#    'name': 'peanuts',
#    'parent_tag_name': 'ingredients_to_avoid',
#    'root_tag_type': 'ingredients_to_avoid',
#    'type': 'ingredients_to_avoid'},
#   {'display_name': 'Thomas Meal Planning',
#    'id': 10688655,
#    'name': 'thomas_meal_planning',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Budget',
#    'id': 10742773,
#    'name': 'budget',
#    'parent_tag_name': 'cooking_style',
#    'root_tag_type': 'cooking_style',
#    'type': 'cooking_style'},
#   {'display_name': 'Tillamook Bag',
#    'id': 10912100,
#    'name': 'tillamook_bag',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'BJs Meal Planning',
#    'id': 10919556,
#    'name': 'bjs_meal_planning',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'Mccormick Wednesday',
#    'id': 10945407,
#    'name': 'mccormick_wednesday',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Mccormick Saturday',
#    'id': 10945410,
#    'name': 'mccormick_saturday',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'McCormick More Inspiration',
#    'id': 10956868,
#    'name': 'mccormick_more_inspiration',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Thomas Meal Planning 3',
#    'id': 11002783,
#    'name': 'thomas_meal_planning_3',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'McCormick Meal Planning',
#    'id': 11003772,
#    'name': 'mccormick_meal_planning',
#    'parent_tag_name': None,
#    'root_tag_type': 'business_tags',
#    'type': 'business_tags'},
#   {'display_name': 'KH Dippin',
#    'id': 11024934,
#    'name': 'kh_dippin',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Cap One Starters',
#    'id': 11173648,
#    'name': 'cap_one_starters',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Cap One Sweets',
#    'id': 11173649,
#    'name': 'cap_one_sweets',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Cap One Breakfast',
#    'id': 11173651,
#    'name': 'cap_one_breakfast',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'},
#   {'display_name': 'Brandon',
#    'id': 11230774,
#    'name': 'brandon',
#    'parent_tag_name': None,
#    'root_tag_type': 'feature_page',
#    'type': 'feature_page'}],
#  'prev': None,
#  'next': None}

# %% [markdown]
# You will need to pass these `headers` with every HTTP request to the API. The API key (X-RapidAPI-Key) is how the server keeps track of how many requests you have made.

# %% [markdown]
# Please have a look at [the documentation](https://rapidapi.com/apidojo/api/tasty). Click on some of the different endpoints. Notice that this brings up a form that you can fill in, which generates the corresponding code. (By default, it's set to Node.js. You should set it to Python.)

# %% [markdown]
# ## Question 1
#
# You would like to cook the daikon (an Asian radish) in your fridge. You would like to find recipes that involve daikon.
#
# Which endpoint would you use? Issue an HTTP request to the endpoint, and convert the JSON response to a `DataFrame` using `json_normalize`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Question 2
#
# Find recipes containing avocado. Among recipes with over 500 reviews, which one had the highest score (proportion of positive reviews)?
#
# There are hundreds of results, but the API only returns 20 results by default (and a maximum of 40 results, even if you specify the `size=` parameter). You will need to use a `for` loop, incrementing the `from=` parameter. Be sure to respect the API's rate limits (or you may be blocked!)

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Question 3
#
# Take the avocado JSON data from above (you do not need to read in the data from the REST API again). How many recipes are vegetarian? You should be able to identify this from the "tags" attribute.
#
# _Hint:_ Try flattening the data so that there is one row for each tag.

# %%
# YOUR CODE HERE

# %% [markdown]
# Now you can use the Tasty API to help you decide what's for dinner!
