# %% [markdown]
# # Ensemble Methods
#
# "Ensemble methods" are ways of combining predictions from multiple machine learning models to obtain even better predictions.
#
# In this Colab, you will try ensembling your best machine learning model from the Kaggle competition with another student's model and see if you obtain even better predictions!

# %% [markdown]
# ## Preparation
#
# This Colab is designed to be done with a partner during section.
#
# The only preparation you need to do _before_ section is to identify a machine learning model from Lab 4B that you will ensemble with a partner's. Copy over the model definition for your best model from Lab 4B. If the best model took a long time to fit, you may want to consider choosing the next-best model.

# %%
import pandas as pd

# YOUR CODE HERE

# %% [markdown]
# Make predictions on the test set and upload the predictions to the now-completed [Kaggle competition](https://www.kaggle.com/competitions/how-bitter-is-the-beer-datasci-112-w-26).
#
# Record the error on the test set.

# %%
df_test = pd.read_csv("https://dlsun.github.io/pods/data/beer/beer_test.csv")

# YOUR CODE HERE

# %% [markdown]
# ## Exercise 0
#
# Find a partner in section. Copy the model definition for your partner's model here.

# %%
# YOUR (PARTNER'S) CODE HERE

# %% [markdown]
# ## Exercise 1 (Voting)
#
# **Voting** is the simplest ensemble method. The predictions from the individual models are simply averaged to obtain the final prediction.
#
# Ensemble your two models together using sklearn's [`VotingRegressor`](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingRegressor.html). (Read the documentation to learn how to use `VotingRegressor`.)
#
# Use cross-validation to evaluate whether the voting ensemble is better than each model individually.

# %%
from sklearn.ensemble import VotingRegressor

# YOUR CODE HERE

# %% [markdown]
# Moment of truth! Use your ensemble model to make predictions on the test data, and upload to the now-completed [Kaggle competition](https://www.kaggle.com/competitions/how-bitter-is-the-beer-datasci-112-w-26). How does the voting ensemble compare to each model individually, in terms of test error?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Exercise 2 (Stacking)
#
# **Stacking** is when another machine learning model is trained on top of the predictions from the individual machine learning models to obtain the final machine learning model.
#
# Ensemble your two models together using sklearn's [`StackingRegressor`](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html), using linear regression to combine the predictions. (Read the documentation to learn how to use `StackingRegressor`.)
#
# Use cross-validation to evaluate how the stacking ensemble compares to each model individually and the voting ensemble.

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import LinearRegression

# YOUR CODE HERE

# %% [markdown]
# Moment of truth! Use your ensemble model to make predictions on the test data, and upload to the now-completed [Kaggle competition](https://www.kaggle.com/competitions/how-bitter-is-the-beer-datasci-112-w-26). How does the stacking ensemble compare to the others in terms of test error?

# %%
# YOUR CODE HERE
